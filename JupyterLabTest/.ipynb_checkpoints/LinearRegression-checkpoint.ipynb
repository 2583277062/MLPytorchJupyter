# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %%
def synthetic_data(w,b,num_examples):
    X = torch.normal(0,1,(num_examples,len(w)))
    y = torch.matmul(X,w)+b
    y += torch.normal(0,0.01,y.shape)
    return X,y.reshape((-1,1))

# %%
true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        batch_indices = torch.tensor(indices[i:min(i+batch_size,num_examples)])
        yield features[batch_indices], labels[batch_indices]

# %%
features.shape
# Out:
# torch.Size([1000, 2])

# %%
labels.shape
# Out:
# torch.Size([1000, 1])

# %%
for X,y in data_iter(10, features,labels):
    print(X,'\n',y)
    break
# Out:
# tensor([[ 0.9452, -0.5156],
#         [ 0.1778, -1.2388],
#         [ 0.8901, -1.2389],
#         [ 1.6264,  1.0279],
#         [-0.1160,  1.1192],
#         [ 0.3085, -1.1466],
#         [ 1.5220,  0.9238],
#         [ 0.5405, -0.2869],
#         [-0.6283, -0.4086],
#         [ 0.8614,  0.8537]])
#  tensor([[ 7.8460],
#         [ 8.7926],
#         [10.1906],
#         [ 3.9671],
#         [ 0.1712],
#         [ 8.7296],
#         [ 4.0973],
#         [ 6.2497],
#         [ 4.3415],
#         [ 3.0327]])

# %%
w = torch.normal(0, 0.01, size=(2,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
w
# Out:
# tensor([[-0.0153],
#         [-0.0103]], requires_grad=True)

# %%
b
# Out:
# tensor([0.], requires_grad=True)

# %%
def linreg(X, w, b):  #@save
    """线性回归模型。"""
    return torch.matmul(X, w) + b

# %%
def squared_loss(y_hat, y):  #@save
    """均方损失。"""
    return (y_hat - y.reshape(y_hat.shape)) ** 2 / 2

# %%
def sgd(params,lr,batch_size):
    with torch.no_grad():
        for param in params:
#             print(param.grad)
            param -= lr * param.grad/batch_size
            param.grad.zero_()

# %%
num_epochs = 10
lr = 0.01
net = linreg
loss = squared_loss

for epoch in range(num_epochs):
    for X,y in data_iter(20,features,labels):
        l = loss(net(X,w,b),y)
        l.sum().backward()
        sgd([w,b],lr,20)
#         print(f'epoch{epoch}, w:{w},b:{b}')
    with torch.no_grad():
        train_l = loss(net(features,w,b),labels)
        print(f'epoch:{epoch},loss:{float(train_l.mean())}')
# Out:
# tensor([[-36.8219],
#         [ 83.2989]])
# tensor([-100.4669])
# tensor([[-32.7280],
#         [ 37.2366]])
# tensor([-75.5994])
# tensor([[-29.6631],
#         [ 66.1067]])
# tensor([-86.4405])
# tensor([[-40.6382],
#         [138.1700]])
# tensor([-99.9269])
# tensor([[-26.3859],
#         [ 69.9018]])
# tensor([-65.7105])
# tensor([[-45.2882],
#         [110.9313]])
# tensor([-100.0244])
# tensor([[-32.8179],
#         [ 42.5560]])
# tensor([-56.1907])
# tensor([[-55.6428],
#         [ 64.2510]])
# tensor([-80.3556])
# tensor([[-0.4751],
#         [33.5869]])
# tensor([-44.0193])
# tensor([[-18.5309],
#         [ 24.8674]])
# tensor([-56.3696])
# tensor([[-76.6604],
#         [ 97.9218]])
# tensor([-74.9514])
# tensor([[-19.0969],
#         [ 18.6644]])
# tensor([-55.1770])
# tensor([[-10.7064],
#         [ 91.8528]])
# tensor([-81.8081])
# tensor([[-13.9412],
#         [ 30.5314]])
# tensor([-73.8649])
# tensor([[ 1.6479],
#         [59.7332]])
# tensor([-65.6827])
# tensor([[-25.5801],
#         [ 68.7411]])
# tensor([-82.4447])
# tensor([[-68.8744],
#         [ 58.7466]])
# tensor([-70.3303])
# tensor([[-34.5564],
#         [ 33.2278]])
# tensor([-55.4441])
# tensor([[-30.2930],
#         [ 52.4706]])
# tensor([-58.0340])
# tensor([[-24.3393],
#         [ 55.6432]])
# tensor([-83.5241])
# tensor([[-44.1073],
#         [ 60.0149]])
# tensor([-95.3803])
# tensor([[-36.9310],
#         [ 51.9026]])
# tensor([-80.4606])
# tensor([[-40.9869],
#         [ 33.1625]])
# tensor([-71.5555])
# tensor([[-101.0170],
#         [  67.2470]])
# tensor([-85.5949])
# tensor([[-5.5934],
#         [36.4934]])
# tensor([-64.3559])
# tensor([[-23.9492],
#         [ 90.4577]])
# tensor([-71.7875])
# tensor([[-1.6894],
#         [54.0135]])
# tensor([-70.6380])
# tensor([[-12.9389],
#         [ 43.6938]])
# tensor([-69.8815])
# tensor([[-40.7130],
#         [ 64.0062]])
# tensor([-83.7221])
# tensor([[-15.4147],
#         [ 34.0043]])
# tensor([-47.3671])
# tensor([[-38.5147],
#         [ 80.5831]])
# tensor([-83.0516])
# tensor([[-67.8551],
#         [ 63.2471]])
# tensor([-60.3756])
# tensor([[-20.0632],
#         [  8.9942]])
# tensor([-45.9769])
# tensor([[-18.7250],
#         [ 31.4083]])
# tensor([-41.1048])
# tensor([[ 2.1803],
#         [41.9274]])
# tensor([-37.4273])
# tensor([[-19.0289],
#         [ 69.4038]])
# tensor([-62.3043])
# tensor([[-31.3086],
#         [ 41.8461]])
# tensor([-64.6399])
# tensor([[-49.9614],
#         [ 47.6968]])
# tensor([-44.1189])
# tensor([[ 1.1698],
#         [73.5669]])
# tensor([-75.7183])
# tensor([[-20.7429],
#         [ 31.6805]])
# tensor([-39.2172])
# tensor([[-14.4140],
#         [ 35.7771]])
# tensor([-55.6449])
# tensor([[-34.9062],
#         [ 35.3399]])
# tensor([-52.9519])
# tensor([[-17.2360],
#         [ 39.1237]])
# tensor([-47.3010])
# tensor([[-55.0725],
#         [ 38.8741]])
# tensor([-53.5817])
# tensor([[-51.8629],
#         [ 41.7240]])
# tensor([-52.0333])
# tensor([[-39.9923],
#         [ 46.0886]])
# tensor([-45.7698])
# tensor([[-58.7819],
#         [ 55.5740]])
# tensor([-43.0531])
# tensor([[-10.6364],
#         [ 87.5935]])
# tensor([-57.0751])
# tensor([[-65.9787],
#         [ 43.4313]])
# tensor([-44.3351])
# tensor([[-67.2178],
#         [ 24.6422]])
# tensor([-67.3709])
# epoch:0,loss:6.069054126739502
# tensor([[-65.5212],
#         [ 47.2331]])
# tensor([-64.0926])
# tensor([[-29.1829],
#         [ 53.1394]])
# tensor([-67.4865])
# tensor([[11.2181],
#         [45.7216]])
# tensor([-53.9507])
# tensor([[-33.8386],
#         [ 49.9095]])
# tensor([-55.7409])
# tensor([[-44.6372],
#         [ 33.0454]])
# tensor([-60.3920])
# tensor([[-14.0986],
#         [ 49.2068]])
# tensor([-37.7589])
# tensor([[-23.2154],
#         [ -0.2167]])
# tensor([-29.0512])
# tensor([[-19.9478],
#         [ 38.3766]])
# tensor([-51.5279])
# tensor([[ 9.0581],
#         [18.5983]])
# tensor([-42.2647])
# tensor([[-17.9101],
#         [ 23.6476]])
# tensor([-43.4502])
# tensor([[-32.1808],
#         [ 27.2314]])
# tensor([-55.9028])
# tensor([[-14.2867],
#         [ 15.5648]])
# tensor([-34.2508])
# tensor([[-62.3941],
#         [ 56.2179]])
# tensor([-58.2857])
# tensor([[-35.6963],
#         [ 38.3594]])
# tensor([-52.3009])
# tensor([[-12.5890],
#         [ 18.3922]])
# tensor([-39.2203])
# tensor([[-17.4328],
#         [ 45.7363]])
# tensor([-31.1238])
# tensor([[-1.6055],
#         [14.5404]])
# tensor([-35.3391])
# tensor([[-3.5155],
#         [62.2529]])
# tensor([-44.7761])
# tensor([[-5.5071],
#         [ 9.7051]])
# tensor([-35.4776])
# tensor([[-3.9679],
#         [17.7886]])
# tensor([-40.8698])
# tensor([[-24.6502],
#         [ 34.4885]])
# tensor([-36.3673])
# tensor([[-59.0711],
#         [ 66.7945]])
# tensor([-38.4029])
# tensor([[-4.6363],
#         [24.2030]])
# tensor([-33.5862])
# tensor([[-21.4089],
#         [  5.2782]])
# tensor([-25.4591])
# tensor([[-30.6584],
#         [ 21.0050]])
# tensor([-31.6142])
# tensor([[-19.1867],
#         [ 53.6257]])
# tensor([-42.5205])
# tensor([[-39.2416],
#         [ 64.3482]])
# tensor([-57.2665])
# tensor([[-18.4025],
#         [ 24.6444]])
# tensor([-35.6481])
# tensor([[-20.9376],
#         [ 18.2534]])
# tensor([-31.1322])
# tensor([[-17.8726],
#         [ 22.3974]])
# tensor([-35.6563])
# tensor([[-31.9803],
#         [ 47.1767]])
# tensor([-44.9710])
# tensor([[-29.6013],
#         [ 37.6717]])
# tensor([-41.2456])
# tensor([[-35.1438],
#         [ 45.7513]])
# tensor([-47.3611])
# tensor([[-18.5599],
#         [ 32.5183]])
# tensor([-36.0177])
# tensor([[-25.9740],
#         [ 18.7775]])
# tensor([-40.6227])
# tensor([[ 3.7331],
#         [42.8230]])
# tensor([-38.3055])
# tensor([[5.1417e-04],
#         [3.9962e+01]])
# tensor([-39.5930])
# tensor([[-28.0681],
#         [ 35.0348]])
# tensor([-34.1107])
# tensor([[-4.7111],
#         [37.8095]])
# tensor([-30.7251])
# tensor([[-13.5699],
#         [ 33.9423]])
# tensor([-41.5502])
# tensor([[-9.9839],
#         [16.5873]])
# tensor([-24.8863])
# tensor([[-5.4432],
#         [26.1880]])
# tensor([-27.4533])
# tensor([[-7.5653],
#         [17.9712]])
# tensor([-30.6610])
# tensor([[-20.9758],
#         [ 44.1168]])
# tensor([-37.7806])
# tensor([[-22.1271],
#         [ 29.6569]])
# tensor([-34.3456])
# tensor([[-1.0961],
#         [27.2852]])
# tensor([-26.9371])
# tensor([[-25.1455],
#         [ 32.9134]])
# tensor([-45.1700])
# tensor([[-11.9704],
#         [ 14.4334]])
# tensor([-13.5640])
# tensor([[ 0.7805],
#         [20.9371]])
# tensor([-24.4985])
# tensor([[-10.0120],
#         [ 25.5178]])
# tensor([-38.7130])
# epoch:1,loss:2.2192013263702393
# tensor([[-13.0753],
#         [ 29.8035]])
# tensor([-26.3815])
# tensor([[-24.4820],
#         [ 17.0396]])
# tensor([-39.9072])
# tensor([[-19.5809],
#         [ 43.9147]])
# tensor([-33.8983])
# tensor([[ 2.5409],
#         [18.2641]])
# tensor([-15.1928])
# tensor([[-16.8527],
#         [ 36.1439]])
# tensor([-37.0205])
# tensor([[-4.7666],
#         [14.0565]])
# tensor([-20.5543])
# tensor([[-0.3172],
#         [43.5549]])
# tensor([-38.2559])
# tensor([[-2.2598],
#         [30.6190]])
# tensor([-40.1818])
# tensor([[-17.0122],
#         [  9.8562]])
# tensor([-28.3930])
# tensor([[-15.2127],
#         [ 25.9625]])
# tensor([-19.3304])
# tensor([[-16.9060],
#         [ 32.9813]])
# tensor([-23.9449])
# tensor([[-29.8443],
#         [ 24.5823]])
# tensor([-30.6183])
# tensor([[-2.9212],
#         [29.7784]])
# tensor([-25.0507])
# tensor([[-12.5749],
#         [ 14.7184]])
# tensor([-26.4058])
# tensor([[-24.1213],
#         [  4.9489]])
# tensor([-21.6808])
# tensor([[-10.2703],
#         [ 10.0165]])
# tensor([-29.3865])
# tensor([[-15.4626],
#         [ 21.3567]])
# tensor([-29.1025])
# tensor([[-22.0311],
#         [ 20.7158]])
# tensor([-23.7475])
# tensor([[-14.7788],
#         [ 25.5679]])
# tensor([-33.8638])
# tensor([[ 5.2996],
#         [29.5594]])
# tensor([-26.8782])
# tensor([[-15.4173],
#         [  4.2251]])
# tensor([-28.1401])
# tensor([[-18.5712],
#         [ 33.6465]])
# tensor([-32.2104])
# tensor([[-14.4518],
#         [ 44.1458]])
# tensor([-35.3942])
# tensor([[-19.3243],
#         [ 24.2671]])
# tensor([-29.2343])
# tensor([[-17.5432],
#         [ 25.2363]])
# tensor([-27.4046])
# tensor([[-12.3910],
#         [ 15.4239]])
# tensor([-23.4220])
# tensor([[-10.3671],
#         [  7.9464]])
# tensor([-19.9145])
# tensor([[-13.5852],
#         [  7.5402]])
# tensor([-13.5717])
# tensor([[-6.2867],
#         [27.3400]])
# tensor([-26.1643])
# tensor([[-0.6926],
#         [22.7372]])
# tensor([-20.2809])
# tensor([[-5.5630],
#         [ 7.4114]])
# tensor([-19.8649])
# tensor([[-13.3508],
#         [ 16.5880]])
# tensor([-18.8534])
# tensor([[-11.9480],
#         [ 11.6468]])
# tensor([-21.6262])
# tensor([[-19.0646],
#         [ 19.9526]])
# tensor([-26.5766])
# tensor([[-22.8978],
#         [ 24.0187]])
# tensor([-27.9063])
# tensor([[1.0486],
#         [9.5952]])
# tensor([-21.8738])
# tensor([[-8.0278],
#         [21.6695]])
# tensor([-21.3393])
# tensor([[-12.0752],
#         [ 18.3059]])
# tensor([-21.0196])
# tensor([[-11.7567],
#         [ 10.7137]])
# tensor([-21.6122])
# tensor([[-12.9094],
#         [ 20.3703]])
# tensor([-9.1506])
# tensor([[-9.7484],
#         [ 8.9062]])
# tensor([-18.5723])
# tensor([[-7.8493],
#         [ 9.3985]])
# tensor([-19.9986])
# tensor([[-1.7782],
#         [24.5339]])
# tensor([-21.8500])
# tensor([[-4.8916],
#         [ 7.5210]])
# tensor([-13.9612])
# tensor([[-15.3022],
#         [ 10.1255]])
# tensor([-18.1685])
# tensor([[-14.4421],
#         [ 11.4073]])
# tensor([-22.2391])
# tensor([[-11.4322],
#         [ 14.9384]])
# tensor([-18.2538])
# tensor([[-8.5717],
#         [ 8.1880]])
# tensor([-15.8230])
# tensor([[-4.2309],
#         [11.0309]])
# tensor([-18.2258])
# tensor([[ 0.1614],
#         [13.4055]])
# tensor([-16.8968])
# epoch:2,loss:0.8118392825126648
# tensor([[-10.0652],
#         [ 21.2175]])
# tensor([-20.3977])
# tensor([[-0.0779],
#         [ 6.6935]])
# tensor([-10.5309])
# tensor([[ 0.0825],
#         [10.5011]])
# tensor([-15.7209])
# tensor([[-14.9460],
#         [  6.7840]])
# tensor([-20.0306])
# tensor([[-18.6261],
#         [ 22.7477]])
# tensor([-23.8275])
# tensor([[-12.5251],
#         [ 12.4030]])
# tensor([-18.3185])
# tensor([[-9.0350],
#         [ 9.8623]])
# tensor([-17.4000])
# tensor([[-16.6860],
#         [  5.7946]])
# tensor([-14.3008])
# tensor([[-12.3790],
#         [ 15.9731]])
# tensor([-19.6826])
# tensor([[-1.3352],
#         [ 7.6834]])
# tensor([-15.1038])
# tensor([[1.1052],
#         [4.4905]])
# tensor([-11.3989])
# tensor([[-4.8845],
#         [12.9573]])
# tensor([-14.9083])
# tensor([[-8.4764],
#         [11.8810]])
# tensor([-17.4559])
# tensor([[-6.2901],
#         [13.2361]])
# tensor([-17.5521])
# tensor([[-2.6597],
#         [ 6.0260]])
# tensor([-12.7939])
# tensor([[-16.2936],
#         [ 10.2077]])
# tensor([-9.6978])
# tensor([[-5.0720],
#         [ 8.3288]])
# tensor([-15.8215])
# tensor([[-3.0685],
#         [10.5411]])
# tensor([-12.9958])
# tensor([[-4.7888],
#         [12.9121]])
# tensor([-14.1607])
# tensor([[-9.1504],
#         [16.4908]])
# tensor([-21.6883])
# tensor([[-17.8130],
#         [ 18.3731]])
# tensor([-23.2112])
# tensor([[-9.9914],
#         [15.0214]])
# tensor([-18.3967])
# tensor([[-5.0594],
#         [ 6.2224]])
# tensor([-14.4053])
# tensor([[-5.0435],
#         [19.6630]])
# tensor([-14.5170])
# tensor([[-1.5250],
#         [ 9.6541]])
# tensor([-12.6001])
# tensor([[-7.9362],
#         [16.8009]])
# tensor([-20.7300])
# tensor([[-4.0325],
#         [14.1534]])
# tensor([-15.4530])
# tensor([[-5.3111],
#         [12.2527]])
# tensor([-16.8119])
# tensor([[-5.4458],
#         [ 8.5562]])
# tensor([-4.9705])
# tensor([[-5.8800],
#         [ 9.0743]])
# tensor([-10.2666])
# tensor([[ 1.2980],
#         [18.9484]])
# tensor([-17.9237])
# tensor([[10.0475],
#         [14.4936]])
# tensor([-12.7271])
# tensor([[-13.8660],
#         [ 10.6355]])
# tensor([-17.3974])
# tensor([[-9.1083],
#         [ 8.6631]])
# tensor([-11.3757])
# tensor([[-3.2714],
#         [-0.0102]])
# tensor([-8.7591])
# tensor([[-9.9036],
#         [ 4.9242]])
# tensor([-9.0675])
# tensor([[-8.5828],
#         [16.1492]])
# tensor([-14.8792])
# tensor([[-1.2088],
#         [ 6.5905]])
# tensor([-10.7155])
# tensor([[-8.3776],
#         [15.3984]])
# tensor([-15.8199])
# tensor([[-0.7399],
#         [16.6641]])
# tensor([-18.9849])
# tensor([[-20.8168],
#         [ 18.2989]])
# tensor([-16.6676])
# tensor([[-5.3731],
#         [ 7.0322]])
# tensor([-14.4720])
# tensor([[-8.6368],
#         [ 3.1648]])
# tensor([-10.9460])
# tensor([[-2.6781],
#         [11.0202]])
# tensor([-13.5241])
# tensor([[-11.2669],
#         [ 18.0350]])
# tensor([-14.9763])
# tensor([[-2.3788],
#         [13.1899]])
# tensor([-12.1028])
# tensor([[-3.3111],
#         [20.2110]])
# tensor([-14.0204])
# tensor([[-5.7339],
#         [ 9.7365]])
# tensor([-11.0327])
# tensor([[-8.0719],
#         [ 7.7290]])
# tensor([-11.0252])
# tensor([[-10.5192],
#         [  8.5818]])
# tensor([-11.1158])
# epoch:3,loss:0.29703250527381897
# tensor([[-6.3981],
#         [ 7.2951]])
# tensor([-8.3747])
# tensor([[-3.3417],
#         [11.9070]])
# tensor([-11.3786])
# tensor([[-6.0947],
#         [13.6555]])
# tensor([-13.6016])
# tensor([[0.5554],
#         [1.2263]])
# tensor([-8.2584])
# tensor([[-5.3613],
#         [ 5.3142]])
# tensor([-9.5602])
# tensor([[-7.3807],
#         [ 6.3598]])
# tensor([-10.6848])
# tensor([[-3.8911],
#         [ 6.9741]])
# tensor([-9.2188])
# tensor([[-4.3696],
#         [ 6.8573]])
# tensor([-10.0539])
# tensor([[-7.8901],
#         [ 9.9474]])
# tensor([-12.8599])
# tensor([[-2.2664],
#         [ 8.4238]])
# tensor([-9.6505])
# tensor([[-2.4509],
#         [ 7.9957]])
# tensor([-11.7880])
# tensor([[-1.1708],
#         [ 4.6238]])
# tensor([-6.9529])
# tensor([[-4.4057],
#         [ 3.3257]])
# tensor([-10.1597])
# tensor([[-5.5415],
#         [12.4433]])
# tensor([-11.1102])
# tensor([[-5.3907],
#         [12.8322]])
# tensor([-9.9108])
# tensor([[-1.6628],
#         [ 7.5876]])
# tensor([-10.6938])
# tensor([[-6.5813],
#         [13.5569]])
# tensor([-9.0094])
# tensor([[-6.7327],
#         [ 5.5540]])
# tensor([-8.4056])
# tensor([[2.8984],
#         [6.3366]])
# tensor([-8.8049])
# tensor([[-6.3996],
#         [ 7.0925]])
# tensor([-10.2387])
# tensor([[-3.3305],
#         [13.2445]])
# tensor([-10.9870])
# tensor([[-3.6690],
#         [ 3.1555]])
# tensor([-10.0616])
# tensor([[-2.8944],
#         [ 7.1343]])
# tensor([-8.9706])
# tensor([[-6.0700],
#         [ 3.2010]])
# tensor([-9.0416])
# tensor([[-13.1816],
#         [  8.2766]])
# tensor([-10.9943])
# tensor([[-6.7421],
#         [ 6.0381]])
# tensor([-9.4842])
# tensor([[-1.9235],
#         [ 2.1395]])
# tensor([-6.7753])
# tensor([[-8.0345],
#         [ 8.8862]])
# tensor([-9.5342])
# tensor([[-3.0296],
#         [ 7.3977]])
# tensor([-8.7537])
# tensor([[-1.0388],
#         [ 7.8465]])
# tensor([-6.9647])
# tensor([[-3.5782],
#         [ 2.4878]])
# tensor([-5.7370])
# tensor([[-4.5700],
#         [ 5.3002]])
# tensor([-10.8068])
# tensor([[-3.4170],
#         [ 6.1025]])
# tensor([-9.2544])
# tensor([[-1.0317],
#         [ 8.6633]])
# tensor([-8.6347])
# tensor([[-3.2857],
#         [ 2.1085]])
# tensor([-4.7921])
# tensor([[-3.7326],
#         [ 4.1201]])
# tensor([-7.8530])
# tensor([[-2.5723],
#         [ 7.3925]])
# tensor([-9.4087])
# tensor([[0.7034],
#         [6.4924]])
# tensor([-8.2990])
# tensor([[-5.8956],
#         [ 3.3250]])
# tensor([-5.8949])
# tensor([[-3.0498],
#         [ 9.4086]])
# tensor([-9.0227])
# tensor([[-2.7036],
#         [ 8.2589]])
# tensor([-6.5258])
# tensor([[-3.0475],
#         [ 5.1401]])
# tensor([-7.0060])
# tensor([[-7.7470],
#         [ 7.8061]])
# tensor([-8.4218])
# tensor([[-6.4317],
#         [ 9.5037]])
# tensor([-10.6144])
# tensor([[-0.1269],
#         [ 7.6178]])
# tensor([-7.9705])
# tensor([[-7.6416],
#         [ 9.5916]])
# tensor([-9.0663])
# tensor([[-2.7895],
#         [ 4.9622]])
# tensor([-7.9132])
# tensor([[-1.6600],
#         [ 4.1641]])
# tensor([-4.7555])
# tensor([[-5.7073],
#         [ 6.5480]])
# tensor([-9.7505])
# tensor([[-4.1214],
#         [ 6.0619]])
# tensor([-8.4644])
# epoch:4,loss:0.10875067859888077
# tensor([[-3.9813],
#         [ 7.0667]])
# tensor([-6.5547])
# tensor([[-2.1630],
#         [ 4.8225]])
# tensor([-8.4893])
# tensor([[-1.2969],
#         [ 4.2211]])
# tensor([-5.5369])
# tensor([[-3.6454],
#         [ 0.5224]])
# tensor([-5.4409])
# tensor([[0.8869],
#         [6.3736]])
# tensor([-5.2347])
# tensor([[-4.2636],
#         [ 2.5142]])
# tensor([-6.7282])
# tensor([[-3.5199],
#         [ 4.7338]])
# tensor([-5.6672])
# tensor([[-3.2993],
#         [ 5.4616]])
# tensor([-7.6919])
# tensor([[-4.1342],
#         [ 2.8999]])
# tensor([-6.0309])
# tensor([[-2.1013],
#         [ 8.7248]])
# tensor([-5.7231])
# tensor([[-1.1825],
#         [ 5.6167]])
# tensor([-6.4940])
# tensor([[-3.0996],
#         [ 6.3557]])
# tensor([-7.6853])
# tensor([[-1.8768],
#         [ 1.7781]])
# tensor([-4.6727])
# tensor([[0.8837],
#         [4.5643]])
# tensor([-5.0098])
# tensor([[-1.7870],
#         [ 3.0475]])
# tensor([-5.9903])
# tensor([[-3.3809],
#         [ 5.2013]])
# tensor([-6.0533])
# tensor([[-3.0662],
#         [ 2.7025]])
# tensor([-5.3096])
# tensor([[-2.8874],
#         [ 8.4630]])
# tensor([-5.3671])
# tensor([[-5.7276],
#         [ 5.9120]])
# tensor([-6.7560])
# tensor([[-1.5517],
#         [ 2.5146]])
# tensor([-5.9140])
# tensor([[-2.2046],
#         [ 4.3145]])
# tensor([-4.9960])
# tensor([[-3.0539],
#         [ 3.7907]])
# tensor([-6.1062])
# tensor([[-0.6879],
#         [ 4.6479]])
# tensor([-6.8760])
# tensor([[-3.1412],
#         [ 4.9374]])
# tensor([-7.8446])
# tensor([[-1.5155],
#         [ 3.8771]])
# tensor([-5.8582])
# tensor([[-4.5944],
#         [ 3.4639]])
# tensor([-4.9728])
# tensor([[-2.1665],
#         [ 4.2519]])
# tensor([-5.8051])
# tensor([[-0.4633],
#         [ 3.8069]])
# tensor([-4.5445])
# tensor([[-2.5966],
#         [ 1.4672]])
# tensor([-5.3090])
# tensor([[-2.3276],
#         [ 5.0699]])
# tensor([-5.9243])
# tensor([[-3.4245],
#         [ 2.5316]])
# tensor([-4.7252])
# tensor([[-1.6588],
#         [ 2.7294]])
# tensor([-5.1991])
# tensor([[-3.6922],
#         [ 4.4290]])
# tensor([-5.4786])
# tensor([[-3.2004],
#         [ 4.9967]])
# tensor([-6.1590])
# tensor([[-1.8214],
#         [ 4.1923]])
# tensor([-4.0723])
# tensor([[-1.6798],
#         [ 2.5789]])
# tensor([-5.2043])
# tensor([[-4.0116],
#         [ 2.0419]])
# tensor([-4.3495])
# tensor([[-2.8257],
#         [ 5.5113]])
# tensor([-5.3640])
# tensor([[-4.6730],
#         [ 4.2564]])
# tensor([-5.5133])
# tensor([[-3.7562],
#         [ 4.3236]])
# tensor([-5.9146])
# tensor([[-1.0334],
#         [ 4.4333]])
# tensor([-3.8304])
# tensor([[-1.1625],
#         [ 5.0726]])
# tensor([-4.3024])
# tensor([[-1.6969],
#         [ 6.3012]])
# tensor([-4.8407])
# tensor([[-0.3620],
#         [ 4.5469]])
# tensor([-5.2253])
# tensor([[-3.0735],
#         [ 1.0188]])
# tensor([-3.1255])
# tensor([[-4.0940],
#         [ 5.1684]])
# tensor([-5.2049])
# tensor([[-1.8901],
#         [ 4.8494]])
# tensor([-4.8576])
# tensor([[-1.2297],
#         [ 2.8774]])
# tensor([-3.4079])
# tensor([[-2.4478],
#         [ 1.7219]])
# tensor([-3.5810])
# tensor([[-1.5196],
#         [ 4.2531]])
# tensor([-4.8216])
# epoch:5,loss:0.039849694818258286
# tensor([[0.0808],
#         [2.7291]])
# tensor([-3.9283])
# tensor([[-1.5423],
#         [ 1.0931]])
# tensor([-3.9575])
# tensor([[-1.4592],
#         [ 3.9135]])
# tensor([-4.0097])
# tensor([[-2.2119],
#         [ 2.3461]])
# tensor([-3.7321])
# tensor([[-2.2418],
#         [ 4.2577]])
# tensor([-4.4900])
# tensor([[-2.4974],
#         [ 3.2061]])
# tensor([-4.4289])
# tensor([[-2.5961],
#         [ 1.5964]])
# tensor([-4.0862])
# tensor([[-0.4914],
#         [ 2.8062]])
# tensor([-4.1199])
# tensor([[-1.5253],
#         [ 3.0841]])
# tensor([-3.7786])
# tensor([[-3.4595],
#         [ 4.2575]])
# tensor([-3.6217])
# tensor([[-3.4149],
#         [ 3.5087]])
# tensor([-4.8526])
# tensor([[-1.6205],
#         [ 1.1252]])
# tensor([-2.9375])
# tensor([[-2.8724],
#         [ 2.0086]])
# tensor([-4.2133])
# tensor([[-1.0467],
#         [ 2.5894]])
# tensor([-2.2789])
# tensor([[-1.3209],
#         [ 5.7471]])
# tensor([-4.9758])
# tensor([[-0.5662],
#         [ 2.9231]])
# tensor([-3.4356])
# tensor([[-0.8388],
#         [ 2.0889]])
# tensor([-2.8648])
# tensor([[0.1608],
#         [2.9491]])
# tensor([-4.0527])
# tensor([[-2.7185],
#         [ 3.0892]])
# tensor([-3.8968])
# tensor([[-0.5552],
#         [ 2.8468]])
# tensor([-3.0656])
# tensor([[-1.9261],
#         [ 1.6067]])
# tensor([-3.5651])
# tensor([[-3.5379],
#         [ 1.1431]])
# tensor([-2.7841])
# tensor([[-1.1610],
#         [ 2.0775]])
# tensor([-2.8752])
# tensor([[-2.0752],
#         [ 2.2624]])
# tensor([-3.5873])
# tensor([[-1.7371],
#         [ 2.2826]])
# tensor([-3.6756])
# tensor([[-1.0009],
#         [ 1.3654]])
# tensor([-2.8655])
# tensor([[-3.2107],
#         [ 2.8017]])
# tensor([-3.1796])
# tensor([[-2.4484],
#         [ 1.1092]])
# tensor([-3.1736])
# tensor([[-1.2310],
#         [ 2.4975]])
# tensor([-3.2602])
# tensor([[0.4510],
#         [2.3862]])
# tensor([-3.4699])
# tensor([[-1.5927],
#         [ 1.3317]])
# tensor([-3.5366])
# tensor([[-1.7021],
#         [ 2.8810]])
# tensor([-2.8709])
# tensor([[-1.3896],
#         [ 2.9807]])
# tensor([-1.8639])
# tensor([[-2.3103],
#         [ 1.4820]])
# tensor([-3.7031])
# tensor([[-1.5547],
#         [ 1.4430]])
# tensor([-2.8121])
# tensor([[-1.9094],
#         [ 4.2003]])
# tensor([-3.9647])
# tensor([[-0.2352],
#         [ 2.6832]])
# tensor([-3.2039])
# tensor([[-0.5144],
#         [ 2.4360]])
# tensor([-3.2477])
# tensor([[-0.2423],
#         [ 1.8527]])
# tensor([-2.9520])
# tensor([[-1.6611],
#         [ 2.7832]])
# tensor([-2.9870])
# tensor([[-0.7042],
#         [ 2.2055]])
# tensor([-3.1282])
# tensor([[-1.9075],
#         [ 2.1221]])
# tensor([-2.7730])
# tensor([[-1.1192],
#         [ 1.8634]])
# tensor([-2.5829])
# tensor([[-0.6718],
#         [ 4.1924]])
# tensor([-3.7518])
# tensor([[-2.2879],
#         [ 3.5388]])
# tensor([-2.9646])
# tensor([[-1.6275],
#         [ 2.0998]])
# tensor([-2.7927])
# tensor([[0.8166],
#         [0.7157]])
# tensor([-1.6451])
# tensor([[-0.9551],
#         [ 1.6009]])
# tensor([-2.2977])
# tensor([[-0.8849],
#         [ 2.9107]])
# tensor([-2.3861])
# tensor([[-0.5422],
#         [ 3.6408]])
# tensor([-3.4616])
# epoch:6,loss:0.014619397930800915
# tensor([[-1.0367],
#         [ 0.9990]])
# tensor([-2.2451])
# tensor([[-1.0023],
#         [ 1.1545]])
# tensor([-2.4149])
# tensor([[-1.2210],
#         [ 3.2896]])
# tensor([-2.7224])
# tensor([[-0.9106],
#         [ 2.5462]])
# tensor([-3.0242])
# tensor([[-1.6384],
#         [ 2.5475]])
# tensor([-2.7678])
# tensor([[-0.9055],
#         [ 1.2916]])
# tensor([-2.7072])
# tensor([[-2.3107],
#         [ 4.7436]])
# tensor([-3.3105])
# tensor([[-0.1810],
#         [ 1.0616]])
# tensor([-2.5551])
# tensor([[-0.5918],
#         [ 2.2221]])
# tensor([-2.3205])
# tensor([[-0.4012],
#         [ 2.7269]])
# tensor([-2.4897])
# tensor([[-1.2850],
#         [ 1.9042]])
# tensor([-2.9174])
# tensor([[-1.5819],
#         [ 1.3690]])
# tensor([-2.3134])
# tensor([[-0.4572],
#         [ 0.8145]])
# tensor([-1.6869])
# tensor([[-0.7084],
#         [ 0.6510]])
# tensor([-1.6981])
# tensor([[-0.6667],
#         [ 2.5101]])
# tensor([-2.6879])
# tensor([[-1.4408],
#         [ 1.0132]])
# tensor([-2.1691])
# tensor([[-0.8637],
#         [ 0.7077]])
# tensor([-2.2506])
# tensor([[-0.9293],
#         [ 2.2233]])
# tensor([-1.2484])
# tensor([[-2.0120],
#         [ 1.9723]])
# tensor([-2.6631])
# tensor([[-0.1860],
#         [ 1.1336]])
# tensor([-1.9705])
# tensor([[-0.3471],
#         [ 0.6590]])
# tensor([-2.0502])
# tensor([[-0.6143],
#         [ 1.9218]])
# tensor([-1.8183])
# tensor([[-1.2887],
#         [ 3.0364]])
# tensor([-2.7922])
# tensor([[-0.9001],
#         [ 1.9579]])
# tensor([-2.5291])
# tensor([[-0.6720],
#         [ 1.3093]])
# tensor([-1.9320])
# tensor([[-1.2902],
#         [ 2.1194]])
# tensor([-2.3331])
# tensor([[-0.6434],
#         [ 0.3300]])
# tensor([-1.6714])
# tensor([[-1.7591],
#         [ 2.0369]])
# tensor([-2.1673])
# tensor([[-0.1547],
#         [ 0.7253]])
# tensor([-1.6522])
# tensor([[-0.3813],
#         [ 1.2840]])
# tensor([-1.4458])
# tensor([[-1.5477],
#         [ 2.1728]])
# tensor([-2.0924])
# tensor([[-0.5153],
#         [ 0.6643]])
# tensor([-1.8553])
# tensor([[-1.1009],
#         [ 2.3822]])
# tensor([-2.5013])
# tensor([[-1.0811],
#         [ 1.5798]])
# tensor([-2.0251])
# tensor([[-0.8110],
#         [ 0.9988]])
# tensor([-1.4840])
# tensor([[-0.2214],
#         [ 1.0272]])
# tensor([-1.7023])
# tensor([[-0.4773],
#         [ 1.2246]])
# tensor([-1.9596])
# tensor([[-0.9080],
#         [ 1.3602]])
# tensor([-2.1703])
# tensor([[-0.4180],
#         [ 0.3555]])
# tensor([-1.5268])
# tensor([[-1.0736],
#         [ 0.8979]])
# tensor([-1.3953])
# tensor([[0.2392],
#         [2.3910]])
# tensor([-1.5539])
# tensor([[-0.4759],
#         [ 0.9323]])
# tensor([-1.7786])
# tensor([[-0.1781],
#         [ 1.2886]])
# tensor([-1.4294])
# tensor([[-0.2553],
#         [ 1.1202]])
# tensor([-1.6536])
# tensor([[-1.3265],
#         [ 1.5031]])
# tensor([-1.4157])
# tensor([[-0.6861],
#         [ 0.6762]])
# tensor([-1.4018])
# tensor([[-1.0176],
#         [ 0.8280]])
# tensor([-1.1490])
# tensor([[-1.6268],
#         [ 0.8603]])
# tensor([-2.0012])
# tensor([[-0.7829],
#         [ 0.9756]])
# tensor([-1.0224])
# tensor([[-1.2340],
#         [ 0.5999]])
# tensor([-1.6996])
# epoch:7,loss:0.005383369047194719
# tensor([[-1.0213],
#         [ 1.3341]])
# tensor([-1.7838])
# tensor([[-0.3398],
#         [ 1.0142]])
# tensor([-1.1963])
# tensor([[-0.5914],
#         [ 1.0946]])
# tensor([-1.7006])
# tensor([[-0.3643],
#         [ 1.2777]])
# tensor([-1.7921])
# tensor([[-0.5316],
#         [ 0.8567]])
# tensor([-1.3632])
# tensor([[-0.0801],
#         [ 1.5495]])
# tensor([-1.7077])
# tensor([[-0.5661],
#         [ 1.1271]])
# tensor([-1.5131])
# tensor([[-1.0508],
#         [ 1.8560]])
# tensor([-1.8131])
# tensor([[-0.2724],
#         [ 0.7696]])
# tensor([-1.4058])
# tensor([[-1.2406],
#         [ 0.5822]])
# tensor([-0.9625])
# tensor([[-0.3365],
#         [ 0.7285]])
# tensor([-1.0260])
# tensor([[-0.2047],
#         [ 0.9012]])
# tensor([-1.2315])
# tensor([[-0.5728],
#         [ 1.6050]])
# tensor([-1.1189])
# tensor([[-0.3557],
#         [ 0.5815]])
# tensor([-1.0585])
# tensor([[-0.7971],
#         [ 0.5410]])
# tensor([-1.2094])
# tensor([[-0.7354],
#         [ 0.8704]])
# tensor([-1.1576])
# tensor([[-1.0995],
#         [ 0.6228]])
# tensor([-1.4712])
# tensor([[-0.5312],
#         [ 0.8703]])
# tensor([-1.1698])
# tensor([[-0.3050],
#         [ 1.1323]])
# tensor([-1.3396])
# tensor([[-0.9297],
#         [ 1.0986]])
# tensor([-1.2614])
# tensor([[-0.7604],
#         [ 1.1072]])
# tensor([-1.5056])
# tensor([[0.0924],
#         [1.3239]])
# tensor([-1.2356])
# tensor([[-0.6279],
#         [ 0.5788]])
# tensor([-1.2936])
# tensor([[-0.2182],
#         [ 0.5581]])
# tensor([-1.2644])
# tensor([[-0.9010],
#         [ 0.1201]])
# tensor([-1.2937])
# tensor([[-1.5710],
#         [ 0.7364]])
# tensor([-1.4525])
# tensor([[-0.7407],
#         [ 0.9499]])
# tensor([-1.2072])
# tensor([[0.2540],
#         [1.2013]])
# tensor([-1.3637])
# tensor([[0.0076],
#         [0.7113]])
# tensor([-0.9808])
# tensor([[-1.0265],
#         [ 0.4580]])
# tensor([-1.2171])
# tensor([[-0.6461],
#         [ 1.0315]])
# tensor([-1.0860])
# tensor([[-0.7010],
#         [ 0.4946]])
# tensor([-1.2024])
# tensor([[-0.4674],
#         [ 0.9234]])
# tensor([-1.0733])
# tensor([[-0.3968],
#         [ 1.0032]])
# tensor([-1.2788])
# tensor([[-0.5469],
#         [ 0.9035]])
# tensor([-0.9863])
# tensor([[-0.3701],
#         [ 0.3023]])
# tensor([-0.7868])
# tensor([[-0.4091],
#         [ 0.4321]])
# tensor([-1.2532])
# tensor([[-1.0217],
#         [ 0.7415]])
# tensor([-1.0525])
# tensor([[-0.4130],
#         [ 1.9700]])
# tensor([-1.5591])
# tensor([[0.0003],
#         [0.3063]])
# tensor([-0.8236])
# tensor([[-0.3689],
#         [ 0.7393]])
# tensor([-0.8531])
# tensor([[-0.4923],
#         [ 0.1137]])
# tensor([-0.9378])
# tensor([[-0.7010],
#         [ 0.8925]])
# tensor([-1.1268])
# tensor([[-0.4244],
#         [ 1.0288]])
# tensor([-0.9119])
# tensor([[0.0811],
#         [1.0339]])
# tensor([-0.9632])
# tensor([[-0.0254],
#         [ 0.8993]])
# tensor([-1.1119])
# tensor([[-0.1123],
#         [ 0.7509]])
# tensor([-1.1145])
# tensor([[-0.6389],
#         [ 1.8348]])
# tensor([-1.3925])
# tensor([[-0.4076],
#         [ 0.8806]])
# tensor([-1.2849])
# tensor([[-0.7607],
#         [ 1.2955]])
# tensor([-1.4168])
# epoch:8,loss:0.0020009411964565516
# tensor([[0.1087],
#         [0.4567]])
# tensor([-0.6601])
# tensor([[-0.3089],
#         [ 0.7025]])
# tensor([-0.9475])
# tensor([[0.0135],
#         [1.0928]])
# tensor([-1.1992])
# tensor([[-0.3241],
#         [ 0.3818]])
# tensor([-0.8082])
# tensor([[-0.4107],
#         [ 0.6461]])
# tensor([-0.8906])
# tensor([[-0.2996],
#         [ 0.5856]])
# tensor([-0.7385])
# tensor([[0.0367],
#         [0.8237]])
# tensor([-0.9708])
# tensor([[-0.6989],
#         [ 0.4215]])
# tensor([-0.9456])
# tensor([[0.1922],
#         [0.6303]])
# tensor([-0.9239])
# tensor([[-0.1260],
#         [ 0.6233]])
# tensor([-0.8121])
# tensor([[-0.1866],
#         [ 0.5948]])
# tensor([-0.7782])
# tensor([[-0.6467],
#         [ 0.7869]])
# tensor([-0.9979])
# tensor([[-0.4505],
#         [ 0.4804]])
# tensor([-0.7954])
# tensor([[-0.7698],
#         [ 0.5985]])
# tensor([-0.9955])
# tensor([[-0.3601],
#         [ 0.6617]])
# tensor([-0.9583])
# tensor([[-0.6078],
#         [ 0.4766]])
# tensor([-0.7581])
# tensor([[-0.4073],
#         [ 0.2244]])
# tensor([-0.8425])
# tensor([[-0.4345],
#         [ 1.2590]])
# tensor([-0.7764])
# tensor([[-0.4936],
#         [ 0.2972]])
# tensor([-0.8467])
# tensor([[0.2323],
#         [0.1303]])
# tensor([-0.6090])
# tensor([[-0.4175],
#         [ 0.6096]])
# tensor([-0.8060])
# tensor([[-0.1876],
#         [ 0.9409]])
# tensor([-0.7881])
# tensor([[-0.4103],
#         [ 0.3862]])
# tensor([-0.6921])
# tensor([[-0.1065],
#         [ 0.1133]])
# tensor([-0.5844])
# tensor([[0.1023],
#         [0.8853]])
# tensor([-0.6097])
# tensor([[-0.5920],
#         [ 0.4359]])
# tensor([-0.9294])
# tensor([[-0.4870],
#         [ 0.5575]])
# tensor([-0.9061])
# tensor([[-0.2931],
#         [ 0.5194]])
# tensor([-0.6579])
# tensor([[-0.6018],
#         [ 0.3593]])
# tensor([-0.8396])
# tensor([[-0.5495],
#         [ 0.6693]])
# tensor([-0.9127])
# tensor([[-0.0620],
#         [ 0.6838]])
# tensor([-0.8901])
# tensor([[-0.0168],
#         [ 0.5541]])
# tensor([-0.6630])
# tensor([[-0.6075],
#         [ 0.4293]])
# tensor([-0.8338])
# tensor([[-0.3880],
#         [ 0.8457]])
# tensor([-0.7235])
# tensor([[-0.4090],
#         [ 0.6857]])
# tensor([-0.6450])
# tensor([[-0.2835],
#         [ 0.4682]])
# tensor([-0.7319])
# tensor([[-0.5019],
#         [ 0.8535]])
# tensor([-0.6439])
# tensor([[-0.6203],
#         [ 0.4927]])
# tensor([-0.6302])
# tensor([[-0.4404],
#         [ 0.4052]])
# tensor([-0.6320])
# tensor([[-0.4333],
#         [ 0.4636]])
# tensor([-0.6538])
# tensor([[-0.5239],
#         [ 0.3447]])
# tensor([-0.6991])
# tensor([[-0.2454],
#         [ 0.2107]])
# tensor([-0.5811])
# tensor([[-0.0813],
#         [ 0.5292]])
# tensor([-0.5622])
# tensor([[-0.4839],
#         [ 0.8772]])
# tensor([-0.6090])
# tensor([[-0.2722],
#         [ 0.4199]])
# tensor([-0.7582])
# tensor([[-0.5430],
#         [ 0.4763]])
# tensor([-0.7601])
# tensor([[-0.0991],
#         [ 0.2041]])
# tensor([-0.4322])
# tensor([[-0.1337],
#         [ 0.2772]])
# tensor([-0.4509])
# tensor([[0.0091],
#         [0.3735]])
# tensor([-0.4770])
# tensor([[-0.1103],
#         [ 0.4416]])
# tensor([-0.5876])
# epoch:9,loss:0.0007624251302331686
